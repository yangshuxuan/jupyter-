# %%
from dirsync import sync
from datetime import datetime
import time

# %%
source_path = 'D:\\ScanResults'
target_path = 'H:\\szhzchip\\ScanResults'
while True:
    print("start sync {}".format(datetime.timestamp(datetime.now())))
    sync(source_path, target_path, 'sync') #for syncing one way
    #sync(target_path, source_path, 'sync') #for syncing the opposite way
    print("end sync {}".format(datetime.timestamp(datetime.now())))
    time.sleep(5)
# Out:
# start sync 1609152438.435876
# [Errno 13] Permission denied: 'D:\\ScanResults\\jupyter.tar'
# dirsync finished in 4.98 seconds.
# 8 directories parsed, 0 files copied
#
# there were errors in copying 1 files.
# end sync 1609152443.427115
# start sync 1609152448.427642
# [Errno 13] Permission denied: 'D:\\ScanResults\\jupyter.tar'
# dirsync finished in 4.70 seconds.
# 8 directories parsed, 0 files copied
#
# there were errors in copying 1 files.
# end sync 1609152453.133878
# start sync 1609152458.133887
# [Errno 13] Permission denied: 'D:\\ScanResults\\jupyter.tar'
# dirsync finished in 4.40 seconds.
# 8 directories parsed, 0 files copied
#
# there were errors in copying 1 files.
# end sync 1609152462.546217
# start sync 1609152467.547001
# dirsync finished in 107. seconds.
# 8 directories parsed, 1 files copied
#
# end sync 1609152575.451667
# start sync 1609152580.451775
# dirsync finished in 4.82 seconds.
# 8 directories parsed, 0 files copied
#
# end sync 1609152585.278439
# ...
