# %%
from kafka import KafkaConsumer
from pymongo import MongoClient
from json import loads

# %%
consumer = KafkaConsumer(
    'numtest',
     bootstrap_servers=['localhost:9092'],
     auto_offset_reset='earliest',
     enable_auto_commit=True,
     group_id='my-group',
     value_deserializer=lambda x: loads(x.decode('utf-8')))

# %%
for message in consumer:
    message = message.value
    print('{} is received'.format(message))
# Out:
# {'number': 1} is received
# {'number': 2} is received
# {'number': 3} is received
# {'number': 4} is received
# {'number': 5} is received
# {'number': 6} is received
# {'number': 7} is received
# {'number': 8} is received
# {'number': 9} is received
# {'number': 10} is received
# {'number': 11} is received
# {'number': 12} is received
# {'number': 13} is received
# {'number': 14} is received
# {'number': 15} is received
# {'number': 16} is received
# {'number': 17} is received
# {'number': 18} is received
# {'number': 19} is received
# {'number': 20} is received
# {'number': 21} is received
# {'number': 22} is received
# {'number': 23} is received
# {'number': 24} is received
# {'number': 25} is received
# {'number': 26} is received
# {'number': 27} is received
# {'number': 28} is received
# {'number': 29} is received
# {'number': 30} is received
# {'number': 31} is received
# {'number': 32} is received
# {'number': 33} is received
# {'number': 34} is received
# {'number': 35} is received
# {'number': 36} is received
# {'number': 37} is received
# {'number': 38} is received
# {'number': 39} is received
# {'number': 40} is received
# {'number': 41} is received
# {'number': 42} is received
# {'number': 43} is received
# {'number': 44} is received
# {'number': 45} is received
# {'number': 46} is received
# {'number': 47} is received
# {'number': 48} is received
# {'number': 49} is received
# {'number': 50} is received
# {'number': 51} is received
# {'number': 52} is received
# {'number': 53} is received
# {'number': 54} is received
# {'number': 55} is received
# {'number': 56} is received
# {'number': 57} is received
# {'number': 58} is received
# {'number': 59} is received
# {'number': 60} is received
# {'number': 61} is received
# {'number': 62} is received
# {'number': 63} is received
# {'number': 64} is received
# {'number': 65} is received
# {'number': 66} is received
# {'number': 67} is received
# {'number': 68} is received
# {'number': 69} is received
# {'number': 70} is received
# {'number': 71} is received
# {'number': 72} is received
# {'number': 73} is received
# {'number': 74} is received
# {'number': 75} is received
# {'number': 76} is received
# {'number': 77} is received
# {'number': 78} is received
# {'number': 79} is received
# {'number': 80} is received
# {'number': 81} is received
# {'number': 82} is received
# {'number': 83} is received
# {'number': 84} is received
# {'number': 85} is received
# {'number': 86} is received
# {'number': 87} is received
# {'number': 88} is received
# {'number': 89} is received
# {'number': 90} is received
# {'number': 91} is received
# {'number': 92} is received
# {'number': 93} is received
# {'number': 94} is received
# {'number': 95} is received
# {'number': 96} is received
# {'number': 97} is received
# {'number': 98} is received
# {'number': 99} is received
# {'number': 100} is received
# {'number': 101} is received
# {'number': 102} is received
# {'number': 103} is received
# {'number': 104} is received
# {'number': 105} is received
# {'number': 106} is received
# {'number': 107} is received
# {'number': 108} is received
# {'number': 109} is received
# {'number': 110} is received
# {'number': 111} is received
# {'number': 112} is received
# {'number': 113} is received
# {'number': 114} is received
# {'number': 115} is received
# {'number': 116} is received
# {'number': 117} is received
# {'number': 118} is received
# {'number': 119} is received
# {'number': 120} is received
# {'number': 121} is received
# {'number': 122} is received
# {'number': 123} is received
# {'number': 124} is received
# {'number': 125} is received
# {'number': 126} is received
# {'number': 127} is received
# {'number': 128} is received
# {'number': 129} is received
# {'number': 130} is received
# {'number': 131} is received
# {'number': 132} is received
# {'number': 133} is received
# {'number': 134} is received
# {'number': 135} is received
# {'number': 136} is received
# {'number': 137} is received
# {'number': 138} is received
# {'number': 139} is received
# {'number': 140} is received
# {'number': 141} is received
# {'number': 142} is received
# {'number': 143} is received
# {'number': 144} is received
# {'number': 145} is received
# {'number': 146} is received
# {'number': 147} is received
# {'number': 148} is received
# {'number': 149} is received
# {'number': 150} is received
# {'number': 151} is received
# {'number': 152} is received
# {'number': 153} is received
# {'number': 154} is received
# {'number': 155} is received
# {'number': 156} is received
# {'number': 157} is received
# {'number': 158} is received
# {'number': 159} is received
# {'number': 160} is received
# {'number': 161} is received
# {'number': 162} is received
# {'number': 163} is received
# {'number': 164} is received
# {'number': 165} is received
# {'number': 166} is received
# {'number': 167} is received
# {'number': 168} is received
# {'number': 169} is received
# {'number': 170} is received
# {'number': 171} is received
# {'number': 172} is received
# {'number': 173} is received
# {'number': 174} is received
# {'number': 175} is received
# {'number': 176} is received
# {'number': 177} is received
# {'number': 178} is received
# {'number': 179} is received
# {'number': 180} is received
# {'number': 181} is received
# {'number': 182} is received
# {'number': 183} is received
# {'number': 184} is received
# {'number': 185} is received
# {'number': 186} is received
# {'number': 187} is received
# {'number': 188} is received
# {'number': 189} is received
# {'number': 190} is received
# {'number': 191} is received
# {'number': 192} is received
# {'number': 193} is received
# {'number': 194} is received
# {'number': 195} is received
# {'number': 196} is received
# {'number': 197} is received
# {'number': 198} is received
# {'number': 199} is received
# {'number': 200} is received
# {'number': 201} is received
# {'number': 202} is received
# {'number': 203} is received
# {'number': 204} is received
# {'number': 205} is received
# {'number': 206} is received
# {'number': 207} is received
# {'number': 208} is received
# {'number': 209} is received
# {'number': 210} is received
# {'number': 211} is received
# {'number': 212} is received
# {'number': 213} is received
# {'number': 214} is received
# {'number': 215} is received
# {'number': 216} is received
# {'number': 217} is received
# {'number': 218} is received
# {'number': 219} is received
# {'number': 220} is received
# {'number': 221} is received
# {'number': 222} is received
# {'number': 223} is received
# {'number': 224} is received
# {'number': 225} is received
# {'number': 226} is received
# {'number': 227} is received
# {'number': 228} is received
# {'number': 229} is received
# {'number': 230} is received
# {'number': 231} is received
# {'number': 232} is received
# {'number': 233} is received
# {'number': 234} is received
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-0800cd2b3f48> in <module>
# ----> 1 for message in consumer:
#       2     message = message.value
#       3     print('{} is received'.format(message))
#
# C:\ProgramData\Miniconda3\lib\site-packages\kafka\consumer\group.py in __next__(self)
#    1191             return self.next_v1()
#    1192         else:
# -> 1193             return self.next_v2()
#    1194
#    1195     def next_v2(self):
#
# C:\ProgramData\Miniconda3\lib\site-packages\kafka\consumer\group.py in next_v2(self)
#    1199                 self._iterator = self._message_generator_v2()
#    1200             try:
# -> 1201                 return next(self._iterator)
#    1202             except StopIteration:
#    1203                 self._iterator = None
#
# C:\ProgramData\Miniconda3\lib\site-packages\kafka\consumer\group.py in _message_generator_v2(self)
#    1114     def _message_generator_v2(self):
#    1115         timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116         record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117         for tp, records in six.iteritems(record_map):
#    1118             # Generators are stateful, and it is possible that the tp / records
#
# C:\ProgramData\Miniconda3\lib\site-packages\kafka\consumer\group.py in poll(self, timeout_ms, max_records, update_offsets)
#     653         remaining = timeout_ms
#     654         while True:
# --> 655             records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656             if records:
#     657                 return records
#
# C:\ProgramData\Miniconda3\lib\site-packages\kafka\consumer\group.py in _poll_once(self, timeout_ms, max_records, update_offsets)
#     700
#     701         timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 702         self._client.poll(timeout_ms=timeout_ms)
#     703         # after the long poll, we should check whether the group needs to rebalance
#     704         # prior to returning data so that the group can stabilize faster
#
# C:\ProgramData\Miniconda3\lib\site-packages\kafka\client_async.py in poll(self, timeout_ms, future)
#     600                     timeout = max(0, timeout)  # avoid negative timeouts
#     601
# --> 602                 self._poll(timeout / 1000)
#     603
#     604             # called without the lock to avoid deadlock potential
#
# C:\ProgramData\Miniconda3\lib\site-packages\kafka\client_async.py in _poll(self, timeout)
#     632
#     633         start_select = time.time()
# --> 634         ready = self._selector.select(timeout)
#     635         end_select = time.time()
#     636         if self._sensors:
#
# C:\ProgramData\Miniconda3\lib\selectors.py in select(self, timeout)
#     321         ready = []
#     322         try:
# --> 323             r, w, _ = self._select(self._readers, self._writers, [], timeout)
#     324         except InterruptedError:
#     325             return ready
#
# C:\ProgramData\Miniconda3\lib\selectors.py in _select(self, r, w, _, timeout)
#     312     if sys.platform == 'win32':
#     313         def _select(self, r, w, _, timeout=None):
# --> 314             r, w, x = select.select(r, w, w, timeout)
#     315             return r, w + x, []
#     316     else:
#
# KeyboardInterrupt:
